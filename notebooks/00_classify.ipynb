# %%
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)

# import os
# import shutil
# import cv2
# from qrdet import QRDetector
# from tqdm.notebook import tqdm

# # =========================
# # CONFIG — đường dẫn tuyệt đối
# # =========================
# BASE         = '/content/drive/MyDrive/AI_BaiTapLon/cccd_extraction_src'
# INPUT_FOLDER = os.path.join(BASE, 'data/raw/image_3508')
# FRONT_FOLDER = os.path.join(BASE, 'data/raw/front')
# BACK_FOLDER  = os.path.join(BASE, 'data/raw/back')

# print('BASE tồn tại  :', os.path.exists(BASE))
# print('INPUT tồn tại :', os.path.exists(INPUT_FOLDER))

# # =========================
# # XÓA SẠCH FRONT/BACK
# # =========================
# for folder in [FRONT_FOLDER, BACK_FOLDER]:
#     if os.path.exists(folder):
#         shutil.rmtree(folder)
#     os.makedirs(folder)
#     print('Reset:', folder)

# # =========================
# # INIT DETECTOR
# # =========================
# detector = QRDetector()

# # =========================
# # LẤY DANH SÁCH ẢNH
# # =========================
# image_extensions = {'.jpg', '.jpeg', '.png', '.bmp'}
# image_files = [
#     f for f in os.listdir(INPUT_FOLDER)
#     if os.path.splitext(f)[1].lower() in image_extensions
# ]
# print('Tim thay', len(image_files), 'anh')

# # =========================
# # PHÂN LOẠI
# # =========================
# counts = {'front': 0, 'back': 0, 'error': 0}

# for file_name in tqdm(image_files, desc='Phan loai front/back'):
#     image_path = os.path.join(INPUT_FOLDER, file_name)
#     image      = cv2.imread(image_path)

#     if image is None:
#         shutil.copy(image_path, os.path.join(BACK_FOLDER, file_name))
#         counts['error'] += 1
#         continue

#     try:
#         detections = detector.detect(image=image)
#         if len(detections) > 0:
#             shutil.copy(image_path, os.path.join(FRONT_FOLDER, file_name))
#             counts['front'] += 1
#         else:
#             shutil.copy(image_path, os.path.join(BACK_FOLDER, file_name))
#             counts['back'] += 1
#     except Exception as e:
#         shutil.copy(image_path, os.path.join(BACK_FOLDER, file_name))
#         counts['error'] += 1

# # =========================
# # KẾT QUẢ
# # =========================
# print('===== KET QUA =====')
# print('Mat truoc (front) :', counts['front'], 'anh')
# print('Mat sau   (back)  :', counts['back'],  'anh')
# print('Loi               :', counts['error'], 'anh')
# print('Tong              :', sum(counts.values()), 'anh')
# Out:
# Mounted at /content/drive
# BASE tồn tại  : True
# INPUT tồn tại : True
# Reset: /content/drive/MyDrive/AI_BaiTapLon/cccd_extraction_src/data/raw/front
# Reset: /content/drive/MyDrive/AI_BaiTapLon/cccd_extraction_src/data/raw/back
# Tim thay 3508 anh
# Phan loai front/back:   0%|          | 0/3508 [00:00<?, ?it/s]
# ===== KET QUA =====
# Mat truoc (front) : 1971 anh
# Mat sau   (back)  : 1537 anh
# Loi               : 0 anh
# Tong              : 3508 anh

# %%
# from google.colab import drive
# drive.mount('/content/drive', force_remount=True)

# import os
# import shutil
# import cv2
# from qrdet import QRDetector
# from tqdm.notebook import tqdm

# # =========================
# # CONFIG
# # =========================
# BASE          = '/content/drive/MyDrive/AI_BaiTapLon/cccd_extraction_src'
# INPUT_FOLDER  = os.path.join(BASE, 'data/raw/image_315')
# FRONT_FOLDER  = os.path.join(BASE, 'data/raw/front_315')
# BACK_FOLDER   = os.path.join(BASE, 'data/raw/back_315')

# print('BASE tồn tại  :', os.path.exists(BASE))
# print('INPUT tồn tại :', os.path.exists(INPUT_FOLDER))

# # =========================
# # XÓA SẠCH FRONT_315 / BACK_315
# # =========================
# for folder in [FRONT_FOLDER, BACK_FOLDER]:
#     if os.path.exists(folder):
#         shutil.rmtree(folder)
#     os.makedirs(folder)
#     print('Reset:', folder)

# # =========================
# # INIT DETECTOR
# # =========================
# detector = QRDetector()

# # =========================
# # LẤY DANH SÁCH ẢNH
# # =========================
# image_extensions = {'.jpg', '.jpeg', '.png', '.bmp'}
# image_files = [
#     f for f in os.listdir(INPUT_FOLDER)
#     if os.path.splitext(f)[1].lower() in image_extensions
# ]
# print('Tim thay', len(image_files), 'anh trong image_315')

# # =========================
# # PHÂN LOẠI
# # =========================
# counts = {'front': 0, 'back': 0, 'error': 0}

# for file_name in tqdm(image_files, desc='Phan loai image_315'):
#     image_path = os.path.join(INPUT_FOLDER, file_name)
#     image      = cv2.imread(image_path)

#     if image is None:
#         shutil.copy(image_path, os.path.join(BACK_FOLDER, file_name))
#         counts['error'] += 1
#         continue

#     try:
#         detections = detector.detect(image=image)
#         if len(detections) > 0:
#             shutil.copy(image_path, os.path.join(FRONT_FOLDER, file_name))
#             counts['front'] += 1
#         else:
#             shutil.copy(image_path, os.path.join(BACK_FOLDER, file_name))
#             counts['back'] += 1
#     except Exception as e:
#         shutil.copy(image_path, os.path.join(BACK_FOLDER, file_name))
#         counts['error'] += 1

# # =========================
# # KẾT QUẢ
# # =========================
# print('===== KET QUA image_315 =====')
# print('Mat truoc (front_315) :', counts['front'], 'anh ->', FRONT_FOLDER)
# print('Mat sau   (back_315)  :', counts['back'],  'anh ->', BACK_FOLDER)
# print('Loi                   :', counts['error'], 'anh ->', BACK_FOLDER)
# print('Tong                  :', sum(counts.values()), 'anh')
# Out:
# Mounted at /content/drive
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# BASE tồn tại  : True
# /usr/local/lib/python3.12/dist-packages/qrdet/qrdet.py:129: UserWarning: QRDetector has been updated to use the new YoloV8 model. Use legacy=True when calling detect for backwards compatibility with 1.x versions. Or update to new output (new output is a tuple of dicts, containing several new information (1.x output is accessible through 'bbox_xyxy' and 'confidence').Forget this message if you are reading it from QReader. [This is a first download warning and will be removed at 2.1]
#   warn("QRDetector has been updated to use the new YoloV8 model. Use legacy=True when calling detect "
# INPUT tồn tại : True
# ...

# %%
# !pip install qrdet
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 35.6 MB/s eta 0:00:00
# ...
