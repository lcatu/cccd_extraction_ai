# %%
import os
# Thay thế bằng token của bạn
token = "ghp_xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"
repo_url = f"https://{token}@github.com/lcatu/cccd_extraction_ai.git"
# Clone kho lưu trữ về môi trường Colab
# !git clone {repo_url}
# Di chuyển vào thư mục dự án
os.chdir("cccd_extraction_ai")
print("Đã clone và chuyển vào thư mục dự án!")

# %%
print('test')

# %%
# Cấu hình thông tin cá nhân của bạn (sửa lại tên và email)
# !git config --global user.name "Lê Chí Anh Tú"
# !git config --global user.email "lcattu19@gmail.com"
# Chuyển sang nhánh của bạn (Ví dụ: Tu)
# !git checkout Tu

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
# Di chuyển thẳng vào thư mục Project trên Google Drive của bạn
os.chdir('/content/drive/MyDrive/AI_BaiTapLon/cccd_extraction_src')

# Cập nhật đường link có chứa Token để push không bị hỏi mật khẩu (thay token của bạn vào)
token = "ghp_xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"
# !git remote set-url origin https://{token}@github.com/lcatu/cccd_extraction_ai.git

print("Đã vào thư mục Drive và cài token thành công!")

# %%
# Chỉ thêm đúng file bạn vừa tạo/sửa (nhớ thay đúng tên file của bạn nhé)
# !git add "notebooks/test github.ipynb"

# Tạo commit
# !git commit -m "test"

# Đẩy lên nhánh Tu
# !git push origin HEAD
