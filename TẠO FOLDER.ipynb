# %%
import os
from google.colab import drive
drive.mount('/content/drive')

BASE = '/content/drive/MyDrive/AI_BaiTapLon/cccd_extraction_src'

folders = [
    # data
    'data/raw/images',
    'data/raw/front',
    'data/raw/back',
    'data/augmented/front',
    'data/augmented/train',
    'data/augmented/val',
    'data/augmented/test',
    'data/detection/images/train',
    'data/detection/images/val',
    'data/detection/labels/train',
    'data/detection/labels/val',
    'data/ocr/crops',
    'data/ocr/labels',
    'data/ocr/train',
    'data/ocr/val',

    # models
    'models/pretrained',
    'models/yolo_field',
    'models/vietocr',

    # notebooks
    'notebooks',

    # outputs
    'outputs/logs',
]

for folder in folders:
    path = os.path.join(BASE, folder)
    os.makedirs(path, exist_ok=True)

print('Tạo xong! Cấu trúc folder:')
for root, dirs, files in os.walk(BASE):
    level = root.replace(BASE, '').count(os.sep)
    indent = '│   ' * (level - 1) + '├── ' if level > 0 else ''
    print(f'{indent}{os.path.basename(root)}/')
# Out:
# Mounted at /content/drive
# Tạo xong! Cấu trúc folder:
# cccd_extraction_src/
# ├── data/
# │   ├── raw/
# │   │   ├── image_3508/
# │   │   ├── image_315/
# │   │   ├── front/
# │   │   ├── back/
# │   │   ├── front_315/
# │   │   ├── back_315/
# │   │   ├── chia_nguoi/
# │   │   │   ├── Tu/
# │   │   │   ├── TrangAnh/
# │   │   │   ├── Khoa/
# │   │   │   ├── Chi/
# │   │   ├── front_315_rotated/
# │   │   ├── data_gan_nhan/
# │   │   ├── chia_gan_nhan/
# │   │   │   ├── Tu/
# │   │   │   ├── Chi/
# │   │   │   ├── Khoa/
# │   │   │   ├── TrangAnh/
# │   │   ├── images/
# │   ├── augmented/
# │   │   ├── front/
# │   │   ├── train/
# │   │   ├── val/
# │   │   ├── test/
# │   ├── detection/
# │   │   ├── images/
# │   │   │   ├── val/
# │   │   │   ├── train/
# │   │   ├── labels/
# │   │   │   ├── train/
# │   │   │   ├── val/
# │   ├── ocr/
# │   │   ├── crops/
# │   │   ├── labels/
# │   │   ├── train/
# │   │   ├── val/
# ├── models/
# │   ├── pretrained/
# │   ├── yolo_field/
# │   ├── vietocr/
# ├── notebooks/
# ├── outputs/
# │   ├── logs/
# ├── .git/
# │   ├── hooks/
# │   ├── info/
# │   ├── refs/
# │   │   ├── heads/
# │   │   ├── tags/
# │   │   ├── remotes/
# │   │   │   ├── origin/
# │   ├── objects/
# │   │   ├── pack/
# │   │   ├── info/
# │   │   ├── df/
# │   │   ├── 4b/
# │   │   ├── 26/
# │   │   ├── cf/
# │   │   ├── 4f/
# │   │   ├── 91/
# │   │   ├── e0/
# │   │   ├── 03/
# │   │   ├── ba/
# │   │   ├── dc/
# │   │   ├── ec/
# │   │   ├── 16/
# │   │   ├── f8/
# │   │   ├── 1c/
# │   │   ├── 92/
# │   │   ├── 7f/
# │   │   ├── 87/
# │   │   ├── ea/
# │   │   ├── 23/
# │   │   ├── 39/
# │   │   ├── 79/
# │   │   ├── 40/
# │   │   ├── 15/
# │   │   ├── 96/
# │   │   ├── 3b/
# │   │   ├── 05/
# │   │   ├── e1/
# │   │   ├── 9c/
# │   │   ├── a6/
# │   │   ├── f5/
# │   │   ├── ab/
# │   │   ├── b2/
# │   │   ├── 72/
# │   │   ├── 20/
# │   │   ├── 47/
# │   │   ├── b4/
# │   │   ├── 5a/
# │   │   ├── 44/
# │   │   ├── e4/
# │   │   ├── 6e/
# │   │   ├── 3a/
# │   │   ├── a0/
# │   │   ├── 4d/
# │   │   ├── f9/
# │   │   ├── 6c/
# │   │   ├── 34/
# │   │   ├── cb/
# │   │   ├── f2/
# │   │   ├── 1e/
# │   │   ├── d8/
# │   │   ├── 4e/
# │   │   ├── 9b/
# │   │   ├── 3c/
# │   │   ├── 46/
# │   │   ├── a5/
# │   │   ├── 75/
# │   │   ├── 8e/
# │   │   ├── b7/
# │   │   ├── 42/
# │   │   ├── 6f/
# │   │   ├── 25/
# │   │   ├── 49/
# │   │   ├── 99/
# │   │   ├── 67/
# │   │   ├── 2f/
# │   │   ├── bd/
# │   │   ├── 6b/
# │   │   ├── 3f/
# │   │   ├── a8/
# │   │   ├── fa/
# │   │   ├── 14/
# │   │   ├── c8/
# │   │   ├── 27/
# │   │   ├── 60/
# │   │   ├── 88/
# │   │   ├── 0e/
# │   │   ├── ff/
# │   │   ├── ee/
# │   │   ├── 0f/
# │   │   ├── fb/
# │   │   ├── cc/
# │   │   ├── 5e/
# │   │   ├── 90/
# │   │   ├── 37/
# │   │   ├── 33/
# │   │   ├── 83/
# │   │   ├── 5b/
# │   │   ├── e2/
# │   │   ├── 7c/
# │   │   ├── 48/
# │   │   ├── e7/
# │   │   ├── aa/
# │   │   ├── 66/
# │   │   ├── fd/
# │   │   ├── 01/
# │   │   ├── f1/
# │   │   ├── 5d/
# │   │   ├── 12/
# │   │   ├── e9/
# │   │   ├── d6/
# │   │   ├── d5/
# │   │   ├── 3e/
# │   │   ├── d3/
# │   │   ├── 0d/
# │   │   ├── de/
# │   │   ├── f7/
# │   │   ├── 1b/
# │   │   ├── bc/
# │   │   ├── 1a/
# │   │   ├── a3/
# │   │   ├── 22/
# │   │   ├── b6/
# │   │   ├── f3/
# │   │   ├── 93/
# │   │   ├── 7b/
# │   │   ├── 2e/
# │   │   ├── 30/
# │   │   ├── 1f/
# │   │   ├── 8b/
# │   │   ├── d4/
# │   │   ├── 56/
# │   │   ├── 02/
# │   │   ├── 8f/
# │   │   ├── c1/
# │   │   ├── a7/
# │   │   ├── 50/
# │   │   ├── 41/
# │   │   ├── 38/
# │   │   ├── c5/
# │   │   ├── 7a/
# │   │   ├── bb/
# │   │   ├── 11/
# │   │   ├── 24/
# │   │   ├── 2d/
# │   │   ├── 71/
# │   │   ├── eb/
# │   │   ├── 82/
# │   │   ├── 2b/
# │   │   ├── 19/
# │   │   ├── 28/
# │   │   ├── 4c/
# │   │   ├── a1/
# │   │   ├── 89/
# │   │   ├── 52/
# │   │   ├── c4/
# │   │   ├── 95/
# │   │   ├── c0/
# │   │   ├── db/
# │   │   ├── 81/
# │   │   ├── f6/
# │   │   ├── 43/
# │   │   ├── 08/
# │   │   ├── 58/
# │   │   ├── 55/
# │   │   ├── 31/
# │   │   ├── 85/
# │   │   ├── 10/
# │   │   ├── c6/
# │   │   ├── 32/
# │   │   ├── 8a/
# │   │   ├── 64/
# │   │   ├── 0b/
# │   │   ├── a2/
# │   │   ├── 06/
# │   │   ├── b0/
# │   │   ├── 62/
# │   │   ├── 17/
# │   │   ├── 6a/
# │   │   ├── 45/
# │   │   ├── 36/
# │   │   ├── af/
# │   │   ├── 7d/
# │   │   ├── ce/
# │   │   ├── cd/
# │   │   ├── 63/
# │   │   ├── 07/
# │   │   ├── 97/
# │   │   ├── b8/
# │   │   ├── ae/
# │   │   ├── c3/
# │   │   ├── 13/
# │   │   ├── 18/
# │   │   ├── 8c/
# │   │   ├── 35/
# │   │   ├── 80/
# │   │   ├── 8d/
# │   │   ├── c9/
# │   │   ├── a4/
# │   │   ├── 7e/
# │   │   ├── c7/
# │   │   ├── 51/
# │   │   ├── fc/
# │   │   ├── 86/
# │   │   ├── 9f/
# │   │   ├── e6/
# │   │   ├── 65/
# │   │   ├── be/
# │   │   ├── 9a/
# │   │   ├── a9/
# │   │   ├── 04/
# │   │   ├── 94/
# │   │   ├── bf/
# │   │   ├── b3/
# │   │   ├── 76/
# │   │   ├── 98/
# │   │   ├── b5/
# │   │   ├── 59/
# │   │   ├── f0/
# │   │   ├── 9e/
# │   │   ├── 77/
# │   │   ├── ef/
# │   │   ├── 78/
# │   │   ├── 29/
# │   │   ├── 84/
# │   │   ├── 4a/
# │   │   ├── 0a/
# │   │   ├── e8/
# │   │   ├── ca/
# │   │   ├── b9/
# │   │   ├── 3d/
# │   │   ├── 53/
# │   │   ├── 69/
# │   │   ├── 1d/
# │   │   ├── 2a/
# │   │   ├── ad/
# │   │   ├── ac/
# │   │   ├── fe/
# │   │   ├── da/
# │   │   ├── 5c/
# │   │   ├── d0/
# │   │   ├── 68/
# │   │   ├── 61/
# │   │   ├── b1/
# │   │   ├── 0c/
# │   │   ├── 9d/
# │   │   ├── ed/
# │   │   ├── 21/
# │   │   ├── 74/
# │   │   ├── 2c/
# │   │   ├── 09/
# │   │   ├── dd/
# │   │   ├── 00/
# │   │   ├── 73/
# │   │   ├── d7/
# │   │   ├── d1/
# │   │   ├── 5f/
# │   │   ├── 70/
# │   │   ├── d2/
# │   │   ├── e3/
# │   │   ├── f4/
# │   │   ├── c2/
# │   │   ├── e5/
# │   │   ├── 54/
# │   │   ├── 57/
# │   │   ├── 6d/
# │   │   ├── d9/
# │   ├── logs/
# │   │   ├── refs/
# │   │   │   ├── heads/
# │   │   │   ├── remotes/
# │   │   │   │   ├── origin/
